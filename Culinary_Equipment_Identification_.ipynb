# %% [markdown]
# <a href="https://colab.research.google.com/github/Dulon18/Machine_Learning_project/blob/main/Culinary_Equipment_Identification_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install tensorflow-gpu

# %%
#pip install Keras

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
 print(keras.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # **Importing Libraries**

# %%
#Deep learning libraries
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPool2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # **Displaying Images**

# %%
picture_size=48
folder_path ='/content/drive/MyDrive/Culinary Equipment/'

# %%
equipment = 'Mesurement_cup'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'Mixer'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'Ovens'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'Vegetable_CuttersChoppers'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'Whisk'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'fork'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'frypan'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
equipment = 'kettles'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'knife'

plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %%
equipment = 'spoon'
plt.style.use('dark_background')
plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+ "Train/" + equipment +'/' + os.listdir(folder_path + "Train/" + equipment)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %% [markdown]
# # **Making Training and Validation Data**

# %%
batch_size = 128

datagen_train = ImageDataGenerator()
datagen_val = ImageDataGenerator()


train_set = datagen_train.flow_from_directory(folder_path + 'Train',
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale", batch_size=batch_size,
                                              class_mode = 'categorical',
                                              shuffle = True)


test_set = datagen_val.flow_from_directory(folder_path + 'validation',
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale", batch_size=batch_size,
                                              class_mode = 'categorical',
                                              shuffle = False)
# Out:
# Found 1000 images belonging to 10 classes.
# Found 400 images belonging to 10 classes.

# %% [markdown]
# # **Model Building**

# %%
no_of_classes=10

model = Sequential()

#1st Layer

model.add(Conv2D(64, (3,3) , padding = 'same', input_shape = (48,48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25)) 

#2nd Layer

model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25)) 


#3rd Layer

model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


#4th Layer

model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())

#Fully connected 1st layer

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

#Fully connected 2nd layer

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes,activation='softmax'))

opti=Adam()
model.compile(optimizer=opti,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 128)       512
# ...

# %% [markdown]
# # **Fitting the Model with Training and validation data**

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau

checkpoint =ModelCheckpoint("./model.h5", monitor='val_acc', verbose=1, save_best_only = True, model='max') 


early_stopping = EarlyStopping(monitor='val_loss', min_delta=0,patience=3,verbose=1, restore_best_weights=True)


reduce_lerningrate = ReduceLROnPlateau(monitor='val_loss', factor =0.2,min_delta=0.0001,patience=3,verbose=1)


callbacks_list =[early_stopping,checkpoint,reduce_lerningrate]

epoch=30

# %%
history = model.fit_generator(generator=train_set,
                              steps_per_epoch=train_set.n//train_set.batch_size,
                              epochs=epoch,
                              validation_data= test_set,
                              validation_steps = test_set.n//test_set.batch_size,callbacks=callbacks_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 1/7 [===>..........................] - ETA: 4:22 - loss: 2.7953 - accuracy: 0.1016
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 7/7 [==============================] - 308s 44s/step - loss: 2.3888 - accuracy: 0.2030 - val_loss: 46.6260 - val_accuracy: 0.1094
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/30
# 7/7 [==============================] - 52s 8s/step - loss: 2.0485 - accuracy: 0.2867 - val_loss: 41.3300 - val_accuracy: 0.1198
# ...

# %% [markdown]
# # **Ploting Accuracy & Loss**

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.suptitle("Optimizer : Adam" , fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=16)
plt.plot(history.history['loss'],  label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.legend(loc='upper right')


plt.subplot(1,2,2)
plt.ylabel('Accuracy' , fontsize=16)
plt.xlabel('Epochs', fontsize=16)
plt.plot(history.history['accuracy'],  label='Training accuracy')
plt.plot(history.history['val_accuracy'],  label='Validation accuracy')
plt.legend(loc='lower right')

plt.show()

# %%
# from tensorflow.keras.models import load_model
# model.save('model_inception3.h5')
